# %% [markdown]
# # Cuaderno para realizar la exploracion en la busqueda de estaciones vecinas
# Para realizar este proceso comenzamos utilizando el catalogo de estaciones que proporciona el IDEAM a traves del DHIME, para de esta forma obtener coordenadas geograficas, nivel de altura y zonas hidrograficas de todas las estaciones del pais.

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---------------------------------------- 96.5/96.5 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Leemos  el archivo XLSX
catalogue = pd.read_excel("../RecursosYDocumentos/DatosEstaciones/CNE_IDEAM.xls")

print(catalogue.columns)
# listamos el lsitado de zonas hidrográficas
catalogue['ZONA_HIDROGRAFICA'].unique()
# Out:
# Index(['CODIGO', 'NOMBRE', 'CATEGORIA', 'TECNOLOGIA', 'ESTADO',
#        'FECHA_INSTALACION', 'FECHA_SUSPENSION', 'ALTITUD', 'LATITUD',
#        'LONGITUD', 'DEPARTAMENTO', 'MUNICIPIO', 'AREA_OPERATIVA', 'ENTIDAD',
#        'AREA_HIDROGRAFICA', 'ZONA_HIDROGRAFICA', 'SUBZONA_HIDROGRAFICA',
#        'CORRIENTE', 'OBSERVACION', 'SUBRED', 'CODIGO REAL'],
#       dtype='object')
# array(['Patía', 'Cauca', 'Nechí', 'Alto Magdalena', 'Caribe - Litoral',
#        'Sogamoso', 'Meta', 'Caquetá', 'Medio Magdalena', 'Cesar', 'Sinú',
#        'Catatumbo', 'Inírida', 'Atrato - Darién', 'Caribe - Guajira',
#        'Bajo Magdalena', 'Arauca', 'Bajo Magdalena- Cauca -San Jorge',
#        'Guaviare', 'Caguán', 'Pacífico - Directos', 'San Juán',
#        'Putumayo', 'Saldaña', 'Casanare', 'Tomo', 'Orinoco Directos',
#        'Tapaje - Dagua - Directos', 'Islas Caribe', 'Amazonas - Directos',
#        'Vaupes', 'Vichada', 'Baudó - Directos Pacifico', 'Yarí', 'Mira',
#        'Apaporis'], dtype=object)

# %%
# Filtramos por la zona hidrográfica 'Magdalena Medio'
catalogue = catalogue[catalogue['ZONA_HIDROGRAFICA'] == 'Medio Magdalena']
catalogue.count()
# Out:
# CODIGO                  421
# NOMBRE                  421
# CATEGORIA               421
# TECNOLOGIA              421
# ESTADO                  421
# FECHA_INSTALACION       421
# FECHA_SUSPENSION        197
# ALTITUD                 421
# LATITUD                 421
# LONGITUD                421
# DEPARTAMENTO            421
# MUNICIPIO               421
# AREA_OPERATIVA          421
# ENTIDAD                 421
# AREA_HIDROGRAFICA       421
# ZONA_HIDROGRAFICA       421
# SUBZONA_HIDROGRAFICA    421
# CORRIENTE               154
# OBSERVACION             124
# SUBRED                  117
# CODIGO REAL              16
# dtype: int64

# %%
# Revisamos los tipos de estaciones
catalogue['CATEGORIA'].unique()
# Out:
# array(['Agrometeorológica', 'Sinóptica Principal', 'Climática Ordinaria',
#        'Pluviográfica', 'Pluviométrica', 'Meteorológica Especial',
#        'Climática Principal', 'Limnigráfica', 'Limnimétrica',
#        'Radio Sonda', 'Sinóptica Secundaria'], dtype=object)

# %%
# Filtramos por que el tipo de estación no este entre 'Limnigráfica', 'Limnimétrica', 'Radio Sonda' y 'Metereológica Marina' puesto a que no tienen valores de precipitación
catalogue = catalogue[~catalogue['CATEGORIA'].isin(['Limnigráfica', 'Limnimétrica', 'Radio Sonda', 'Metereológica Marina'])]
catalogue.count()
# Out:
# CODIGO                  269
# NOMBRE                  269
# CATEGORIA               269
# TECNOLOGIA              269
# ESTADO                  269
# FECHA_INSTALACION       269
# FECHA_SUSPENSION        103
# ALTITUD                 269
# LATITUD                 269
# LONGITUD                269
# DEPARTAMENTO            269
# MUNICIPIO               269
# AREA_OPERATIVA          269
# ENTIDAD                 269
# AREA_HIDROGRAFICA       269
# ZONA_HIDROGRAFICA       269
# SUBZONA_HIDROGRAFICA    269
# CORRIENTE                 3
# OBSERVACION              73
# SUBRED                   87
# CODIGO REAL               3
# dtype: int64

# %%
# Obtenemos los valores para los que existe el valor en la columna 'CODIGO REAL', reemplazamos todas las cadenas por NaN y casteamos a entero
catalogue_depured = catalogue.copy()
catalogue_depured['CODIGO REAL'] = pd.to_numeric(catalogue_depured['CODIGO REAL'], errors='coerce')

catalogue_depured = catalogue_depured.astype({'CODIGO REAL': 'Int64'})

catalogue_depured['CODIGO'] = catalogue_depured['CODIGO REAL'].fillna(catalogue_depured['CODIGO'])
catalogue_depured = catalogue.drop(columns=['CODIGO REAL', 'FECHA_INSTALACION', 'FECHA_SUSPENSION', 'AREA_OPERATIVA', 'OBSERVACION', 'SUBRED', 'CORRIENTE', 'ENTIDAD', 'ESTADO'])
catalogue_depured.head()
# Out:
#       CODIGO                                     NOMBRE            CATEGORIA  \
# 15  23195240                 AGUACHICA - AUT [23195240]    Agrometeorológica
# 28  24055070  SAN  VICENTE DE CHUCURI  - AUT [24055070]    Agrometeorológica
# 35  23085200          AEROPUERTO J M CORDOVA [23085200]  Sinóptica Principal
# 36  23175020                  AEROPUERTO OTU [23175020]  Climática Ordinaria
# 52  23080950                       VIENTO EL [23080950]        Pluviográfica
#
#                    TECNOLOGIA  ALTITUD   LATITUD   LONGITUD DEPARTAMENTO  \
# 15  Automática con Telemetría      103  8.123417 -73.579861        Cesar
# 28  Automática con Telemetría     1093  6.823390 -73.472060    Santander
# 35  Automática sin Telemetría     2073  6.168611 -75.425833    Antioquia
# 36               Convencional      643  7.011750 -74.716306    Antioquia
# 52               Convencional      890  6.400000 -75.100000    Antioquia
#
#                  MUNICIPIO AREA_HIDROGRAFICA ZONA_HIDROGRAFICA  \
# 15               Aguachica   Magdalena Cauca   Medio Magdalena
# 28  San Vicente De Chucurí   Magdalena Cauca   Medio Magdalena
# 35                Rionegro   Magdalena Cauca   Medio Magdalena
# 36                Remedios   Magdalena Cauca   Medio Magdalena
# 52              Alejandría   Magdalena Cauca   Medio Magdalena
#
#                                  SUBZONA_HIDROGRAFICA
# 15  Quebrada El Carmen y Otros Directos al Magdalena
# 28                                           Río Opón
# 35                                           Río Nare
# 36        Río Cimitarra y otros directos al Magdalena
# 52                                           Río Nare

# %% [markdown]
# Una vez que estamos en este punto, procedemos a aplicar los distintos filtros que nos permitiran saber que estaciones son vecinas de que otras. Procedemos a realizar una propuesta sobre como tomar los rangos de altura y precipitación. Primero empezamos con el rango de altura, para el cual utilizamos los rangos definidos por Bernal et al. 2010.
#
# **Tabla 1. Rangos de Elevación y Precipitación Media Anual Multianual**
#
# | RANGO | ELEVACIÓN (msnm) | PRECIPITACIÓN MEDIA ANUAL MULTIANUAL (mm) |
# |-------|------------------|-------------------------------------------|
# | 1     | ≤300             | ≤500                                      |
# | 2     | 301-600          | 501.1-1,000                               |
# | 3     | 601-900          | 1,001.1-1,500                             |
# | 4     | 901-1,200        | 1,501.1-2,000                             |
# | 5     | 1,201-1,500      | 2,001.1-2,500                             |
# | 6     | 1,501-1,800      | 2,501.1-3,000                             |
# | 7     | 1,801-2,100      | 3,001.1-3,500                             |
# | 8     | 2,101-2,400      | 3,501.1-4,000                             |
# | 9     | 2,401-2,700      | 4,001.1-4,500                             |
# | 10    | ≥2,700           | ≥5,000                                    |
#
# Fuente: Bernal et al., 2010

# %%
rangos_elevacion = [
    (float('-inf'), 300, 1),
    (301, 600, 2),
    (601, 900, 3),
    (901, 1200, 4),
    (1201, 1500, 5),
    (1501, 1800, 6),
    (1801, 2100, 7),
    (2101, 2400, 8),
    (2401, 2700, 9),
    (2701, float('inf'), 10)
]

def asignar_rango_elevacion(elevacion):
    for min_elev, max_elev, rango in rangos_elevacion:
        if min_elev <= elevacion <= max_elev:
            return rango
    return None

catalogue_depured['RANGO_ALTITUD'] = catalogue_depured['ALTITUD'].apply(asignar_rango_elevacion)

# %% [markdown]
# Obtenemos el promedio multianual de todas las estaciones de la zona hidrografica

# %%
import os

path = '../datos/imputados_SARIMA/'
zonas_hidrograficas = ['MAGDALENA_MEDIO']

precipitaciones = [
    (0, 500, 1),
    (501, 1000, 2),
    (1001, 1500, 3),
    (1501, 2000, 4),
    (2001, 2500, 5),
    (2501, 3000, 6),
    (3001, 3500, 7),
    (3501, 4000, 8),
    (4001, 4500, 9),
    (4501, float('inf'), 10)

]

def asignar_rango_precipitacion(precipitacion):
    for min_prec, max_prec, rango in precipitaciones:
        if min_prec <= precipitacion <= max_prec:
            return rango
    return None

multi_anual_means = []

for zona_hidrografica in zonas_hidrograficas:
    file_path = f'{path}{zona_hidrografica}/'

    for file in os.listdir(file_path):
        code = file.split('.')[0]
        estacion = pd.read_csv(f'{file_path}/{file}')
        estacion = estacion.groupby('Año').agg({'Precipitación_imputada': 'sum'}).reset_index()
        estacion['Promedio_anual'] = estacion['Precipitación_imputada']

        promedio_multianual = estacion['Promedio_anual'].mean()

        multi_anual_means.append({
            'Codigo': code,
            'Promedio_multianual': promedio_multianual
        })
    multi_anual_means_df = pd.DataFrame(multi_anual_means)
    multi_anual_means_df['RANGO_PRECIPITACION'] = multi_anual_means_df['Promedio_multianual'].apply(asignar_rango_precipitacion)
    multi_anual_means_df.to_csv(f'../datos/promedio_multianual_{zona_hidrografica}.csv', index=False)

# %%
multi_anual_means_df = multi_anual_means_df.astype({'Codigo': 'int32'})
catalogue_total = catalogue_depured.astype({'CODIGO': 'int32'})
catalogue_total = multi_anual_means_df.merge(catalogue_total, left_on='Codigo', right_on='CODIGO', how='left')

catalogue_total
# Out:
#        Codigo  Promedio_multianual  RANGO_PRECIPITACION    CODIGO  \
# 0    23010020          2700.737710                    6  23010020
# 1    23010080          1180.834031                    3  23010080
# 2    23020080          3286.438921                    7  23020080
# 3    23020090          1883.395630                    4  23020090
# 4    23020100          3786.197664                    8  23020100
# ..        ...                  ...                  ...       ...
# 128  23210160          1335.398800                    3  23210160
# 129  23215030          1302.234262                    3  23215030
# 130  23215050          2916.340578                    6  23215050
# 131  25020970          1689.780044                    4  25020970
# 132  26155150          1436.707284                    3  26155150
#
#                           NOMBRE            CATEGORIA  \
# 0             EDEN EL [23010020]        Pluviométrica
# 1         IDEMA-HONDA [23010080]        Pluviométrica
# 2          MANZANARES [23020080]        Pluviométrica
# 3           MARULANDA [23020090]        Pluviométrica
# 4         VICTORIA LA [23020100]        Pluviométrica
# ..                           ...                  ...
# 128           GAMARRA [23210160]        Pluviométrica
# 129      AGUAS CLARAS [23215030]        Pluviométrica
# 130           MATA LA [23215050]        Pluviométrica
# 131            ARENAL [25020970]        Pluviométrica
# 132  LAS BRISAS - AUT [26155150]  Climática Principal
#
#                                   TECNOLOGIA  ALTITUD   LATITUD   LONGITUD  \
# 0                               Convencional     1670  5.154299 -75.047878
# 1                               Convencional     2508  5.201417 -74.749583
# 2                               Convencional     1974  5.265611 -75.144083
# 3                               Convencional     2813  5.278100 -75.267200
# 4                               Convencional      760  5.321083 -74.914639
# ..                                       ...      ...       ...        ...
# 128                             Convencional      150  8.326667 -73.737778
# 129                             Convencional      208  8.228889 -73.602778
# 130                             Convencional      163  8.614444 -73.636389
# 131                             Convencional       74  8.459444 -73.941111
# 132  Automática con Telemetría, Convencional     4133  4.934528 -75.350389
#
#     DEPARTAMENTO   MUNICIPIO AREA_HIDROGRAFICA ZONA_HIDROGRAFICA  \
# 0         Tolima      Fresno   Magdalena Cauca   Medio Magdalena
# 1         Tolima       Honda   Magdalena Cauca   Medio Magdalena
# 2         Caldas  Manzanares   Magdalena Cauca   Medio Magdalena
# 3         Caldas   Marulanda   Magdalena Cauca   Medio Magdalena
# 4         Caldas    Victoria   Magdalena Cauca   Medio Magdalena
# ..           ...         ...               ...               ...
# 128        Cesar     Gamarra   Magdalena Cauca   Medio Magdalena
# 129        Cesar   Aguachica   Magdalena Cauca   Medio Magdalena
# 130        Cesar   La Gloria   Magdalena Cauca   Medio Magdalena
# 131      Bolivar      Arenal   Magdalena Cauca   Medio Magdalena
# 132       Caldas  Villamaria   Magdalena Cauca   Medio Magdalena
#
#                                   SUBZONA_HIDROGRAFICA  RANGO_ALTITUD
# 0                                            Río Gualí              6
# 1                                            Río Gualí              9
# 2                                          Río Guarinó              7
# 3                                          Río Guarinó             10
# 4                                          Río Guarinó              3
# ..                                                 ...            ...
# 128  Quebrada El Carmen y Otros Directos al Magdalena               1
# 129  Quebrada El Carmen y Otros Directos al Magdalena               1
# 130  Quebrada El Carmen y Otros Directos al Magdalena               1
# 131              Directos al Magdalena (Brazo Morales)              1
# 132                                          Río Gualí             10
#
# [133 rows x 16 columns]

# %% [markdown]
# Generamos ahora la tabla de matriz de ponderaciones espaciales para la zona hidrografica.

# %%
! pip install scipy
! pip install pysal
# Out:
# Requirement already satisfied: scipy in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from scipy) (1.26.4)
# Collecting pysal
#   Downloading pysal-24.1-py3-none-any.whl.metadata (16 kB)
# Collecting libpysal>=4.6.2 (from pysal)
#   Downloading libpysal-4.11.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting access>=1.1.8 (from pysal)
#   Downloading access-1.1.9-py3-none-any.whl.metadata (2.4 kB)
# Collecting esda>=2.4.1 (from pysal)
#   Downloading esda-2.5.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting giddy>=2.3.3 (from pysal)
#   Downloading giddy-2.3.5-py3-none-any.whl.metadata (6.4 kB)
# Collecting inequality>=1.0.0 (from pysal)
#   Downloading inequality-1.0.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pointpats>=2.2.0 (from pysal)
#   Downloading pointpats-2.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting segregation>=2.3.1 (from pysal)
#   Downloading segregation-2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting spaghetti>=1.6.6 (from pysal)
#   Downloading spaghetti-1.7.5.post1-py3-none-any.whl.metadata (12 kB)
# Collecting mgwr>=2.1.2 (from pysal)
#   Downloading mgwr-2.2.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting momepy>=0.5.3 (from pysal)
#   Downloading momepy-0.7.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting spglm>=1.0.8 (from pysal)
#   Downloading spglm-1.1.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting spint>=1.0.7 (from pysal)
#   Downloading spint-1.0.7.tar.gz (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting spreg>=1.2.4 (from pysal)
#   Downloading spreg-1.4.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting spvcm>=0.3.0 (from pysal)
#   Downloading spvcm-0.3.0.tar.gz (5.7 MB)
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#      -- ------------------------------------- 0.4/5.7 MB 12.9 MB/s eta 0:00:01
#      ------ --------------------------------- 0.9/5.7 MB 11.2 MB/s eta 0:00:01
#      ---------- ----------------------------- 1.5/5.7 MB 11.8 MB/s eta 0:00:01
#      -------------- ------------------------- 2.1/5.7 MB 12.2 MB/s eta 0:00:01
#      ------------------ --------------------- 2.7/5.7 MB 12.3 MB/s eta 0:00:01
#      --------------------- ------------------ 3.1/5.7 MB 12.5 MB/s eta 0:00:01
#      ------------------------- -------------- 3.6/5.7 MB 11.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 4.2/5.7 MB 11.6 MB/s eta 0:00:01
#      ------------------------------- -------- 4.5/5.7 MB 11.1 MB/s eta 0:00:01
#      ------------------------------------ --- 5.2/5.7 MB 11.4 MB/s eta 0:00:01
#      -------------------------------------- - 5.5/5.7 MB 11.0 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tobler>=0.8.2 (from pysal)
#   Downloading tobler-0.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting mapclassify>=2.4.3 (from pysal)
#   Downloading mapclassify-2.6.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting splot>=1.1.5.post1 (from pysal)
#   Downloading splot-1.1.5.post1-py3-none-any.whl.metadata (8.8 kB)
# Collecting spopt>=0.4.1 (from pysal)
#   Downloading spopt-0.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting geopandas (from access>=1.1.8->pysal)
#   Downloading geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.3 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from access>=1.1.8->pysal) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from access>=1.1.8->pysal) (2.2.2)
# Requirement already satisfied: requests>=2 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from access>=1.1.8->pysal) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from esda>=2.4.1->pysal) (1.5.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from esda>=2.4.1->pysal) (1.13.1)
# Collecting quantecon>=0.4.7 (from giddy>=2.3.3->pysal)
#   Downloading quantecon-0.7.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting beautifulsoup4>=4.10 (from libpysal>=4.6.2->pysal)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: packaging>=22 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from libpysal>=4.6.2->pysal) (24.0)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from libpysal>=4.6.2->pysal) (4.2.2)
# Collecting shapely>=2.0.1 (from libpysal>=4.6.2->pysal)
#   Downloading shapely-2.0.4-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Collecting networkx>=2.7 (from mapclassify>=2.4.3->pysal)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm>=4.63.0 (from momepy>=0.5.3->pysal)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: matplotlib in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from pointpats>=2.2.0->pysal) (3.9.0)
# Collecting deprecation (from segregation>=2.3.1->pysal)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: joblib in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from segregation>=2.3.1->pysal) (1.4.2)
# Requirement already satisfied: seaborn in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from segregation>=2.3.1->pysal) (0.13.2)
# Collecting numba (from segregation>=2.3.1->pysal)
#   Downloading numba-0.60.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting pyproj>=3 (from segregation>=2.3.1->pysal)
#   Downloading pyproj-3.6.1-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting rtree>=1.0 (from spaghetti>=1.6.6->pysal)
#   Downloading Rtree-1.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Collecting pulp>=2.7 (from spopt>=0.4.1->pysal)
#   Downloading PuLP-2.8.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting rasterio (from tobler>=0.8.2->pysal)
#   Downloading rasterio-1.3.10-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: statsmodels in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from tobler>=0.8.2->pysal) (0.14.2)
# Collecting rasterstats (from tobler>=0.8.2->pysal)
#   Downloading rasterstats-0.19.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.10->libpysal>=4.6.2->pysal)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting fiona>=1.8.21 (from geopandas->access>=1.1.8->pysal)
#   Downloading fiona-1.9.6-cp312-cp312-win_amd64.whl.metadata (51 kB)
#      ---------------------------------------- 0.0/51.5 kB ? eta -:--:--
#      ---------------------------------------- 51.5/51.5 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2024.1)
# Requirement already satisfied: certifi in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2024.2.2)
# Collecting sympy (from quantecon>=0.4.7->giddy>=2.3.3->pysal)
#   Downloading sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->segregation>=2.3.1->pysal)
#   Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (2.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from scikit-learn>=1.0->esda>=2.4.1->pysal) (3.5.0)
# Requirement already satisfied: colorama in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from tqdm>=4.63.0->momepy>=0.5.3->pysal) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.1.2)
# Collecting affine (from rasterio->tobler>=0.8.2->pysal)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs (from rasterio->tobler>=0.8.2->pysal)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting click>=4.0 (from rasterio->tobler>=0.8.2->pysal)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cligj>=0.5 (from rasterio->tobler>=0.8.2->pysal)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting snuggs>=1.4.1 (from rasterio->tobler>=0.8.2->pysal)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Collecting click-plugins (from rasterio->tobler>=0.8.2->pysal)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: setuptools in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (70.0.0)
# Collecting simplejson (from rasterstats->tobler>=0.8.2->pysal)
#   Downloading simplejson-3.19.2-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.6)
# Requirement already satisfied: six in c:\users\nlmal\onedrive - universidad de la rioja\documentos\master\trabajo fin de master\homogenizacionseriesprecipitacion\tfm\lib\site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (1.16.0)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading pysal-24.1-py3-none-any.whl (17 kB)
# Downloading access-1.1.9-py3-none-any.whl (21 kB)
# Downloading esda-2.5.1-py3-none-any.whl (132 kB)
#    ---------------------------------------- 0.0/132.4 kB ? eta -:--:--
#    ---------------------------------------- 132.4/132.4 kB 7.6 MB/s eta 0:00:00
# Downloading giddy-2.3.5-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.1 kB ? eta -:--:--
#    ---------------------------------------- 61.1/61.1 kB ? eta 0:00:00
# Downloading inequality-1.0.1-py3-none-any.whl (15 kB)
# Downloading libpysal-4.11.0-py3-none-any.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 16.8 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 13.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.0/2.8 MB 11.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.5/2.8 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 10.5 MB/s eta 0:00:00
# Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Downloading mgwr-2.2.1-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.9 kB ? eta -:--:--
#    ---------------------------------------- 47.9/47.9 kB ? eta 0:00:00
# Downloading momepy-0.7.0-py3-none-any.whl (277 kB)
#    ---------------------------------------- 0.0/277.8 kB ? eta -:--:--
#    ---------------------------------------- 277.8/277.8 kB 8.4 MB/s eta 0:00:00
# Downloading pointpats-2.4.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.4 kB ? eta -:--:--
#    ---------------------------------------- 58.4/58.4 kB ? eta 0:00:00
# Downloading segregation-2.5-py3-none-any.whl (141 kB)
#    ---------------------------------------- 0.0/141.3 kB ? eta -:--:--
#    ---------------------------------------- 141.3/141.3 kB 8.7 MB/s eta 0:00:00
# Downloading spaghetti-1.7.5.post1-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.1 kB ? eta -:--:--
#    ---------------------------------------- 54.1/54.1 kB 2.9 MB/s eta 0:00:00
# Downloading spglm-1.1.0-py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.4 kB ? eta -:--:--
#    ---------------------------------------- 41.4/41.4 kB ? eta 0:00:00
# Downloading splot-1.1.5.post1-py3-none-any.whl (39 kB)
# Downloading spopt-0.6.0-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.5 kB ? eta -:--:--
#    --------------------------------------- 244.5/244.5 kB 15.6 MB/s eta 0:00:00
# Downloading spreg-1.4.2-py3-none-any.whl (331 kB)
#    ---------------------------------------- 0.0/331.8 kB ? eta -:--:--
#    --------------------------------------- 331.8/331.8 kB 10.4 MB/s eta 0:00:00
# Downloading tobler-0.11.2-py3-none-any.whl (34 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading geopandas-0.14.4-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    -------------------- ------------------- 0.6/1.1 MB 18.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.1 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 14.1 MB/s eta 0:00:00
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
#
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Building wheels for collected packages: spint, spvcm
#   Building wheel for spint (setup.py): started
#   Building wheel for spint (setup.py): finished with status 'done'
#   Created wheel for spint: filename=spint-1.0.7-py3-none-any.whl size=31367 sha256=3dbfe0f09232359cb0c392dbbad4ed062537d608261908a5f7b4017064d1fedc
#   Stored in directory: c:\users\nlmal\appdata\local\pip\cache\wheels\d9\82\ea\d31b72061cd6dc1760ec44a1d3e74408b1e6ca590a3361d3f9
#   Building wheel for spvcm (setup.py): started
#   Building wheel for spvcm (setup.py): finished with status 'done'
#   Created wheel for spvcm: filename=spvcm-0.3.0-py3-none-any.whl size=5777207 sha256=661d8d4a8a5210fefbacd7c2c8087b4652347532d649b0f077bbde4f94d53e78
#   Stored in directory: c:\users\nlmal\appdata\local\pip\cache\wheels\38\00\c6\6725ef15ae08b8c868bbd3ee9829f0ac9d26caebc81051db42
# Successfully built spint spvcm
# Installing collected packages: mpmath, tqdm, sympy, soupsieve, snuggs, simplejson, shapely, rtree, pyproj, pulp, networkx, llvmlite, deprecation, click, attrs, affine, numba, cligj, click-plugins, beautifulsoup4, rasterio, quantecon, mapclassify, fiona, rasterstats, geopandas, libpysal, access, tobler, spreg, segregation, pointpats, momepy, inequality, esda, spvcm, spglm, spaghetti, giddy, spopt, splot, spint, mgwr, pysal
# Successfully installed access-1.1.9 affine-2.4.0 attrs-23.2.0 beautifulsoup4-4.12.3 click-8.1.7 click-plugins-1.1.1 cligj-0.7.2 deprecation-2.1.0 esda-2.5.1 fiona-1.9.6 geopandas-0.14.4 giddy-2.3.5 inequality-1.0.1 libpysal-4.11.0 llvmlite-0.43.0 mapclassify-2.6.1 mgwr-2.2.1 momepy-0.7.0 mpmath-1.3.0 networkx-3.3 numba-0.60.0 pointpats-2.4.0 pulp-2.8.0 pyproj-3.6.1 pysal-24.1 quantecon-0.7.2 rasterio-1.3.10 rasterstats-0.19.0 rtree-1.2.0 segregation-2.5 shapely-2.0.4 simplejson-3.19.2 snuggs-1.4.7 soupsieve-2.5 spaghetti-1.7.5.post1 spglm-1.1.0 spint-1.0.7 splot-1.1.5.post1 spopt-0.6.0 spreg-1.4.2 spvcm-0.3.0 sympy-1.12.1 tobler-0.11.2 tqdm-4.66.4

# %%
from scipy.spatial import distance_matrix
import numpy as np

coords = catalogue_total[['LATITUD', 'LONGITUD']].values
dist_matrix = distance_matrix(coords, coords)

# Crear la matriz de pesos espaciales inversa de la distancia
# Evitar dividir por cero en la diagonal
np.fill_diagonal(dist_matrix, np.nan)
weights = 1 / dist_matrix
np.fill_diagonal(weights, 0)

# %%
mean_precip = catalogue_total['Promedio_multianual'].mean()

# Calcular el numerador del índice de Moran
numerator = 0
for i in range(len(catalogue_total)):
    for j in range(len(catalogue_total)):
        numerator += weights[i, j] * (catalogue_total['Promedio_multianual'][i] - mean_precip) * (catalogue_total['Promedio_multianual'][j] - mean_precip)

# Calcular el denominador del índice de Moran
denominator = np.sum(weights) * np.sum((catalogue_total['Promedio_multianual'] - mean_precip)**2)

# %%
# Calcular el índice de Moran
I = len(catalogue_total) * numerator / denominator

print(f"Índice de Moran I: {I}")
# Out:
# Índice de Moran I: 0.3853500525932986

# %% [markdown]
# Procedemos ahora a realizar una implementacion que busque el indice de Moran teniendo en cuenta diferentes rangos de distancias, para ver cual es la distancia maxima en que dos pares de estaciones cumplan la condicion donde el radio de acción de correlación espacial de precipitación sea significativo. Primero obtenemos el listado de las distancias entre todos los pares de estaciones.

# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance_matrix

df = catalogue_total.copy()

coords = df[['LATITUD', 'LONGITUD']].values
dist_matrix = distance_matrix(coords, coords)

moran_indices = []

# Función para calcular la distancia geodésica (Haversine) entre dos puntos
def haversine(lat1, lon1, lat2, lon2):
    # Convertir grados a radianes
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    # Fórmula de Haversine
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    # Radio de la Tierra en km
    r = 6371
    return c * r

# Calcular la distancia máxima entre cada par de estaciones
distances = []
par_estaciones = []

for i in range(len(df)):
    for j in range(i + 1, len(df)):
        dist = haversine(df['LATITUD'][i], df['LONGITUD'][i], df['LATITUD'][j], df['LONGITUD'][j])
        distances.append(dist)
        par_estaciones.append((df['CODIGO'][i], df['CODIGO'][j]))

# Crear un DataFrame con las distancias y las precipitaciones de cada par de estaciones
dist_df = pd.DataFrame({
    'Estación 1': [p[0] for p in par_estaciones],
    'Estación 2': [p[1] for p in par_estaciones],
    'Distancia': distances
})

dist_df
# Out:
#       Estación 1  Estación 2   Distancia
# 0       23010020    23010080   33.446382
# 1       23010020    23020080   16.330745
# 2       23010020    23020090   27.916648
# 3       23010020    23020100   23.698271
# 4       23010020    23025040   22.008116
# ...          ...         ...         ...
# 8773    23215030    25020970   45.196938
# 8774    23215030    26155150  414.056948
# 8775    23215050    25020970   37.680867
# 8776    23215050    26155150  450.821893
# 8777    25020970    26155150  421.712477
#
# [8778 rows x 3 columns]

# %% [markdown]
# Con este listado, se generan 20 rangos donde cada rango de distancias incluya una proporción igual o similar de pares de estaciones

# %%
# Definimos 20 rangos de posibles de distancias, donde cada rango tenga la misma cantidad de pares de estaciones
num_ranges = 20

dist_df = dist_df.sort_values('Distancia').reset_index(drop=True)

dist_df['Rango'] = pd.qcut(dist_df.index, num_ranges, labels=False)

rangos = dist_df.groupby('Rango')['Distancia'].agg(['min', 'max', 'count'])
rangos = rangos.reset_index()

print(rangos)
# Out:
#     Rango         min         max  count
# 0       0    0.028975   30.117696    439
# 1       1   30.160949   48.838450    439
# 2       2   48.850780   63.072326    439
# 3       3   63.080778   75.787031    439
# 4       4   75.833287   87.595643    439
# 5       5   87.600497  100.406643    439
# 6       6  100.429582  113.435618    438
# 7       7  113.521824  126.513105    439
# 8       8  126.539764  139.634921    439
# 9       9  139.706854  153.934162    439
# 10     10  153.940496  169.497442    439
# 11     11  169.549067  185.895851    439
# 12     12  185.905061  204.047315    439
# 13     13  204.074984  223.528893    438
# 14     14  223.596389  239.467117    439
# 15     15  239.472784  256.731468    439
# 16     16  256.733087  274.801324    439
# 17     17  274.959509  293.953167    439
# 18     18  294.074307  324.290750    439
# 19     19  324.392431  450.821893    439

# %% [markdown]
# Encontramos ahora la matriz de distancias para poder obtener facilmente el indice de Moran, para ello volvemos a utilizar el metodo de Harvesine para obtener la distancia en kilometros.

# %%
import numpy as np
import pandas as pd

df = catalogue_total.copy()

# Función para convertir grados a radianes
def deg2rad(degrees):
    return degrees * np.pi / 180

def haversine_distance_matrix(latlon):
    # Radio de la Tierra en kilómetros
    R = 6371.0

    # Convertir latitud y longitud de grados a radianes
    lat_rad = deg2rad(latlon[:, 0])
    lon_rad = deg2rad(latlon[:, 1])

    # Crear matriz de diferencias en latitud y longitud
    lat_diff = np.subtract.outer(lat_rad, lat_rad)
    lon_diff = np.subtract.outer(lon_rad, lon_rad)

    # Aplicar la fórmula del haversine
    a = np.sin(lat_diff / 2) ** 2 + np.cos(lat_rad[:, None]) * np.cos(lat_rad) * np.sin(lon_diff / 2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    # Distancia en kilómetros
    distance_km = R * c
    return distance_km

coords = df[['LATITUD', 'LONGITUD']].values

# Calcular la matriz de distancias
dist_matrix_km = haversine_distance_matrix(coords)

dist_matrix_km.shape
# Out:
# (133, 133)

# %% [markdown]
# Realizamos la busqueda del indice de Moran para todos aquellos pares de estaciones que cumplan la condicion de tener distancias entre si, menores al rango que se esta buscando en ese momento.

# %%
# Inicializar lista para almacenar los índices de Moran para cada rango
moran_indices_rangos = []

# Calcular el índice de Moran para cada rango de distancia
for k in range(len(rangos)):
    # Crear máscara para seleccionar pares de estaciones dentro del rango
    mask = (dist_matrix_km >= rangos['min'][k]) & (dist_matrix_km < rangos['max'][k])

    # Crear matriz de pesos espaciales inversa de la distancia, evitando dividir por cero en la diagonal
    weights = np.zeros_like(dist_matrix_km)
    np.fill_diagonal(weights, 0)
    weights[mask] = 1 / dist_matrix_km[mask]

    # Media de la precipitación
    mean_precip = df['Promedio_multianual'].mean()

    # Calcular el numerador del índice de Moran
    numerator = 0
    for i in range(len(df)):
        for j in range(len(df)):
            numerator += weights[i, j] * (df['Promedio_multianual'][i] - mean_precip) * (df['Promedio_multianual'][j] - mean_precip)

    # Calcular el denominador del índice de Moran
    denominator = np.sum(weights) * np.sum((df['Promedio_multianual'] - mean_precip) ** 2)

    # Calcular el índice de Moran
    I = len(df) * numerator / denominator if denominator != 0 else np.nan

    moran_indices_rangos.append(I)

# Mostrar los índices de Moran para cada rango
rangos['Índice de Moran'] = moran_indices_rangos
rangos

rangos.to_csv(f'../datos/indice_moran_rangos_{zona_hidrografica}.csv', index=False)

# %% [markdown]
# Graficamos los puntos obtenidos para el indice de Moran.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(rangos['min'], rangos['Índice de Moran'], marker='o')
plt.axhline(0, color='black', linestyle='--')
plt.xlabel('Distancia máxima entre estaciones (km)')
plt.ylabel('Índice de Moran')
plt.title('Índice de Moran en función de los rangos de distancia maxima entre estaciones')
plt.grid(True)
plt.show()

# %% [markdown]
# Realizamos una busqueda de todas aquellas estaciones que cumplan las 4 condiciones para encontrar sus respectivas vecinas. La primera ya la cumplen al estar analizando unicamente una zona hidrografica, partiendo de cada estacion vamos a valorar todas las que puedan ser vecinas que cumplan tener el mismo rango de altura, el mismo rango de precipitaciones y entrarse a maximo 30.117696 Km de disntacia.

# %%
# Realizamos una busqueda de todas aquellas estaciones que cumplan las 4 condiciones para encontrar sus respectivas vecinas. La primera ya la cumplen al estar analizando unicamente una zona hidrografica, partiendo de cada estacion vamos a valorar todas las que puedan ser vecinas que cumplan tener el mismo rango de altura, el mismo rango de precipitaciones y entrarse a maximo 30.117696 Km de disntacia.

vecinas_df = pd.DataFrame(columns=['Rango Altitud', 'Rango Precipitación', 'Estación', 'Vecinas'])

# Definimos las condiciones
# Rango de altitud
for i in range(10):
    # Rango de precipitación
    for j in range(10):
        estaciones = df[(df['RANGO_ALTITUD'] == i + 1) & (df['RANGO_PRECIPITACION'] == j + 1)]
        if len(estaciones) > 0:
            # Calcular la matriz de distancias
            coords = estaciones[['LATITUD', 'LONGITUD']].values
            dist_matrix_km = haversine_distance_matrix(coords)

            # Llenamos la diagonal con NaN
            np.fill_diagonal(dist_matrix_km, np.nan)

            # Crear lista de estaciones vecinas
            vecinas = []
            for l in range(len(estaciones)):
                # Encontrar las estaciones vecinas dentro de la distancia máxima
                vecinas_estacion = estaciones[dist_matrix_km[l] < 30.117696 ]
                vecinas.append(vecinas_estacion['CODIGO'].values)

            # Crear un DataFrame con las estaciones y sus vecinas
            
            range_veci = pd.DataFrame({
                'Rango Altitud': i + 1,
                'Rango Precipitación': j + 1,
                'Estación': estaciones['CODIGO'].values,
                'Vecinas': vecinas
            })

            vecinas_df = pd.concat([vecinas_df, range_veci], ignore_index=True)


vecinas_df.to_csv(f'../datos/estaciones_vecinas_{zona_hidrografica}.csv', index=False)

# %%
vecinas_df[vecinas_df['Estación'] == 23125120]
# Out:
#    Rango Altitud Rango Precipitación  Estación Vecinas
# 46             1                   7  23125120      []

# %%
df1 = dist_df[dist_df['Estación 1'] == 23125120]
df2 = dist_df[dist_df['Estación 2'] == 23125120]

df2 = df2.rename(columns={'Estación 1': 'Estación 2', 'Estación 2': 'Estación 1'})

df_union = pd.concat([df1, df2])

# filtramos buscando la estacion 23120200
df_union[df_union['Estación 2'] == 23120200]
# Out:
#      Estación 1  Estación 2  Distancia  Rango
# 407    23125120    23120200  28.891445      0

# %%
# buscamos las anteriores estaciones en el catalogo
catalogue_total[catalogue_total['CODIGO'].isin([23125120, 23120200])]
# Out:
#       Codigo  Promedio_multianual  RANGO_PRECIPITACION    CODIGO  \
# 58  23120200          2942.685000                    6  23120200
# 69  23125120          3146.067874                    7  23125120
#
#                               NOMBRE            CATEGORIA    TECNOLOGIA  \
# 58  PUERTO ARAUJO ALERTAS [23120200]        Pluviométrica  Convencional
# 69              CIMITARRA [23125120]  Climática Ordinaria  Convencional
#
#     ALTITUD   LATITUD   LONGITUD DEPARTAMENTO  MUNICIPIO AREA_HIDROGRAFICA  \
# 58      118  6.533889 -74.082500    Santander  Cimitarra   Magdalena Cauca
# 69      198  6.308611 -73.952222    Santander  Cimitarra   Magdalena Cauca
#
#    ZONA_HIDROGRAFICA SUBZONA_HIDROGRAFICA  RANGO_ALTITUD
# 58   Medio Magdalena  Río Carare (Minero)              1
# 69   Medio Magdalena  Río Carare (Minero)              1
