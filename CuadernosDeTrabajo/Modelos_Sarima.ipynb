# %% [markdown]
# # Cuaderno de exploración de los modelos ARIMA
# Como funcionan, adicionalmente explroación de las librerias statsmodels y pmdarima.
#
# Empezamos revisando la cantidad de valores nulos que tenemos en un dataframe cualquiera, en este caso, tomamos el primero.

# %%
! pip install matplotlib
! pip install seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp310-cp310-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------------------------------- 165.5/165.5 kB 3.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp310-cp310-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp310-cp310-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 10.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/8.0 MB 11.2 MB/s eta 0:00:01
#    ------- -------------------------------- 1.5/8.0 MB 10.5 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.0 MB 10.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.0 MB 10.6 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.0 MB 10.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.5/8.0 MB 10.6 MB/s eta 0:00:01
#    -------------------- ------------------- 4.0/8.0 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.8/8.0 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/8.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.1/8.0 MB 11.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.7/8.0 MB 12.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 12.1 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.5 kB ? eta -:--:--
#    ---------------------------------------- 187.5/187.5 kB 5.7 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.2 MB 12.9 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.2 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 12.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.2 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 10.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Downloading pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    --------- ------------------------------ 0.6/2.5 MB 18.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.5 MB 12.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.5 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.5 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 12.4 MB/s eta 0:00:00
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas as pd
import numpy as np
import shutil
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Cargamos los datos
path = '../datos/separados_por_estacion/MAGDALENA_MEDIO/'

file = os.listdir(path)[10]
col = file.split('.')[0]
df = pd.read_csv(path+file)

# Buscar columnas con valores nulos
col_null = df.columns[df.isnull().any()].tolist()
print('Cantidad de valores nulos:',df[col_null].isnull().sum())
# Out:
# Cantidad de valores nulos: 23050250    21
# dtype: int64

# %% [markdown]
# Empezamos revisando si la serie de tiempo es estacionaria

# %%
#hacemos un ls de la carpeta
file_test = os.listdir(path)[10]
print(file_test)
col = file_test.split('.')[0]

df = pd.read_csv(path+file_test)

df[col] = df[col].replace(-99999.0, np.nan)

# Graficar la serie de tiempo con el eje x siendo cada dato mensual
# agregamos el valor de cada thickness
plt.figure(figsize=(10, 6))
plt.plot(df[col][0:48], label='Precipitación')
plt.title('Serie de Tiempo de Precipitación')
plt.xlabel('Fecha')
plt.ylabel('Precipitación')
plt.legend()
plt.show()
# Out:
# 23050250.csv

# %% [markdown]
# Visualmente podemos apreciar como si se ve una tendencia estacional que se repite cada 12 datos(es decir cada año), pero igualmente le pasamos una Prueba de Dickey-Fuller Aumentada (ADF) utilizando la libreria statsmodels

# %%
! pip install statsmodels
! pip install pmdarima
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp310-cp310-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from statsmodels) (1.26.4)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.6 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 60.6/60.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from statsmodels) (1.5.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp310-cp310-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB 9.9 MB/s eta 0:00:01
#    -- ------------------------------------- 0.7/9.8 MB 9.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.2/9.8 MB 9.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.8/9.8 MB 10.2 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.8 MB 10.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/9.8 MB 10.1 MB/s eta 0:00:01
#    ------------ --------------------------- 3.2/9.8 MB 10.1 MB/s eta 0:00:01
#    -------------- ------------------------- 3.6/9.8 MB 9.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.0/9.8 MB 10.1 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.8 MB 9.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.8 MB 10.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 10.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 11.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.4/9.8 MB 11.5 MB/s eta 0:00:01
#    -------------------------------- ------- 8.0/9.8 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.8/9.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 11.9 MB/s eta 0:00:00
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#     --------------------------------------- 0.6/46.2 MB 18.5 MB/s eta 0:00:03
#     --------------------------------------- 0.8/46.2 MB 10.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.7/46.2 MB 11.9 MB/s eta 0:00:04
#    -- ------------------------------------- 2.4/46.2 MB 12.6 MB/s eta 0:00:04
#    -- ------------------------------------- 2.9/46.2 MB 12.4 MB/s eta 0:00:04
#    --- ------------------------------------ 3.7/46.2 MB 13.3 MB/s eta 0:00:04
#    --- ------------------------------------ 4.5/46.2 MB 13.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.8/46.2 MB 13.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.3/46.2 MB 13.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.8/46.2 MB 12.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.4/46.2 MB 12.7 MB/s eta 0:00:04
#    ------ --------------------------------- 7.0/46.2 MB 12.5 MB/s eta 0:00:04
#    ------ --------------------------------- 7.6/46.2 MB 12.8 MB/s eta 0:00:04
#    ------- -------------------------------- 8.2/46.2 MB 12.8 MB/s eta 0:00:03
#    ------- -------------------------------- 9.0/46.2 MB 13.0 MB/s eta 0:00:03
#    -------- ------------------------------- 9.4/46.2 MB 12.8 MB/s eta 0:00:03
#    -------- ------------------------------- 9.7/46.2 MB 12.5 MB/s eta 0:00:03
#    -------- ------------------------------- 10.2/46.2 MB 12.4 MB/s eta 0:00:03
#    --------- ------------------------------ 10.5/46.2 MB 12.4 MB/s eta 0:00:03
#    --------- ------------------------------ 11.3/46.2 MB 12.6 MB/s eta 0:00:03
#    --------- ------------------------------ 11.5/46.2 MB 12.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 12.2/46.2 MB 11.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.9/46.2 MB 11.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.6/46.2 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 14.1/46.2 MB 11.7 MB/s eta 0:00:03
#    ------------ --------------------------- 14.9/46.2 MB 12.1 MB/s eta 0:00:03
#    ------------- -------------------------- 15.8/46.2 MB 12.6 MB/s eta 0:00:03
#    -------------- ------------------------- 16.3/46.2 MB 12.6 MB/s eta 0:00:03
#    -------------- ------------------------- 17.0/46.2 MB 12.9 MB/s eta 0:00:03
#    --------------- ------------------------ 17.4/46.2 MB 12.4 MB/s eta 0:00:03
#    --------------- ------------------------ 18.1/46.2 MB 12.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.6/46.2 MB 12.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.5/46.2 MB 12.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.2/46.2 MB 13.4 MB/s eta 0:00:02
#    ------------------ --------------------- 20.8/46.2 MB 13.9 MB/s eta 0:00:02
#    ------------------ --------------------- 21.4/46.2 MB 13.6 MB/s eta 0:00:02
#    ------------------- -------------------- 22.3/46.2 MB 14.6 MB/s eta 0:00:02
#    ------------------- -------------------- 22.8/46.2 MB 14.2 MB/s eta 0:00:02
#    -------------------- ------------------- 23.6/46.2 MB 14.2 MB/s eta 0:00:02
#    -------------------- ------------------- 24.0/46.2 MB 13.9 MB/s eta 0:00:02
#    --------------------- ------------------ 24.5/46.2 MB 13.9 MB/s eta 0:00:02
#    --------------------- ------------------ 25.0/46.2 MB 13.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.6/46.2 MB 13.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 26.0/46.2 MB 12.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 26.4/46.2 MB 12.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.8/46.2 MB 12.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.3/46.2 MB 12.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.5/46.2 MB 11.9 MB/s eta 0:00:02
#    ------------------------ --------------- 27.9/46.2 MB 12.1 MB/s eta 0:00:02
#    ------------------------ --------------- 28.5/46.2 MB 11.7 MB/s eta 0:00:02
#    ------------------------- -------------- 29.0/46.2 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 29.8/46.2 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 30.2/46.2 MB 11.3 MB/s eta 0:00:02
#    -------------------------- ------------- 30.9/46.2 MB 11.3 MB/s eta 0:00:02
#    --------------------------- ------------ 31.4/46.2 MB 11.5 MB/s eta 0:00:02
#    --------------------------- ------------ 32.0/46.2 MB 11.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.6/46.2 MB 11.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 33.2/46.2 MB 10.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.7/46.2 MB 11.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 34.5/46.2 MB 11.7 MB/s eta 0:00:02
#    ------------------------------ --------- 35.2/46.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 35.7/46.2 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 36.1/46.2 MB 11.5 MB/s eta 0:00:01
#    ------------------------------- -------- 36.9/46.2 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 37.5/46.2 MB 12.4 MB/s eta 0:00:01
#    --------------------------------- ------ 38.2/46.2 MB 13.1 MB/s eta 0:00:01
#    --------------------------------- ------ 39.1/46.2 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.5/46.2 MB 13.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.4/46.2 MB 13.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.9/46.2 MB 13.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.4/46.2 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ --- 42.1/46.2 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 43.0/46.2 MB 14.2 MB/s eta 0:00:01
#    ------------------------------------- -- 43.5/46.2 MB 13.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.2/46.2 MB 13.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.7/46.2 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  45.4/46.2 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  45.9/46.2 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 12.6 MB/s eta 0:00:00
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-0.5.6 scipy-1.13.1 statsmodels-0.14.2
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Collecting joblib>=0.11 (from pmdarima)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (1.5.3)
# Collecting scikit-learn>=0.22 (from pmdarima)
#   Downloading scikit_learn-1.5.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (69.5.1)
# Requirement already satisfied: packaging>=17.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.22->pmdarima)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\nlmal\anaconda3\envs\tfm\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp310-cp310-win_amd64.whl (613 kB)
#    ---------------------------------------- 0.0/613.3 kB ? eta -:--:--
#    ------------- -------------------------- 204.8/613.3 kB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 399.4/613.3 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 613.3/613.3 kB 4.8 MB/s eta 0:00:00
# Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/2.8 MB 14.7 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 12.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.0/2.8 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 2.5/2.8 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 11.1 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scikit_learn-1.5.0-cp310-cp310-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/11.0 MB 9.2 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/11.0 MB 9.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/11.0 MB 10.1 MB/s eta 0:00:01
#    ------- -------------------------------- 1.9/11.0 MB 10.3 MB/s eta 0:00:01
#    --------- ------------------------------ 2.5/11.0 MB 11.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/11.0 MB 11.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/11.0 MB 12.0 MB/s eta 0:00:01
#    --------------- ------------------------ 4.3/11.0 MB 11.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.8/11.0 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.6/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.2/11.0 MB 12.3 MB/s eta 0:00:01
#    ------------------------ --------------- 6.7/11.0 MB 12.3 MB/s eta 0:00:01
#    --------------------------- ------------ 7.4/11.0 MB 12.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/11.0 MB 12.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 12.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 13.2 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.0 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 13.1 MB/s eta 0:00:00
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, Cython, scikit-learn, pmdarima
# Successfully installed Cython-3.0.10 joblib-1.4.2 pmdarima-2.0.4 scikit-learn-1.5.0 threadpoolctl-3.5.0

# %%
from statsmodels.tsa.stattools import adfuller

# Realizar la prueba ADF
result = adfuller(df[col].dropna())

# Mostrar los resultados
print('ADF Statistic:', result[0])
print('p-value:', result[1])
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -3.404066776992564
# p-value: 0.010821014248349031
# Critial Values:
#    1%, -3.462980134086401
# Critial Values:
#    5%, -2.875885461947131
# Critial Values:
#    10%, -2.5744164898444515

# %% [markdown]
# Dados los valores que encontramos, ADF es más negativa que todos los valores críticos (tanto al 1%, 5% y 10%) y un el valor p es extremadamente bajo, podemos concluir que la serie de tiempo es estacionaria, razon por la cual no necesitamos diferenciación y por lo mismo podemos asignar el valor 0 al término D del modelo ARIMA. Ahora se procede a identificar el grado de autocorrelacion parcial para hayar el valor del término P. Realizar este proceso es importante porque la PACF muestra la correlación entre una serie de tiempo y sus propios retrasos, eliminando la influencia de los términos intermedios.

# %%
from statsmodels.graphics.tsaplots import plot_pacf

fig, ax = plt.subplots(1, 2, figsize=(18, 8))
ax[0].plot(df[col])
plot_pacf(df[col].dropna(), ax=ax[1])
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt
from pmdarima import auto_arima

df_ARIMA = df[["Fecha", col]]
df_ARIMA['Fecha'] = pd.to_datetime(df_ARIMA['Fecha'])
df_ARIMA.set_index('Fecha', inplace=True)

df_ARIMA = df_ARIMA.dropna()
df_ARIMA

result = adfuller(df_ARIMA[col])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

# Graficar la PACF
plt.figure(figsize=(10, 6))
plot_pacf(df_ARIMA[col], lags=40)
plt.xlabel('Retrasos')
plt.ylabel('Autocorrelación Parcial')
plt.title('Autocorrelograma Parcial de la Precipitación')
plt.show()
# Out:
# ADF Statistic: -3.404066776992564
# p-value: 0.010821014248349031

# %% [markdown]
# En este punto encontramos la funcionalidad de auto_arima que permite encontrar los mejores coeficientes a utilizar para la generación de los modelos. Al tener informacion anual que repite su estacionalidad, marcamos estos valores en la entrada, es decir el parametro seasonal en 'True' y m = 12. El parametro trace lo dejamos tambien en True para obervar como realiza la busqueda.

# %%
model = auto_arima(df_ARIMA[col], seasonal=True, m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.31 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=2937.752, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=2893.237, Time=0.54 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2899.496, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=3282.484, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=2925.102, Time=0.01 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=2892.775, Time=2.36 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=2896.991, Time=3.08 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=2897.524, Time=1.02 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=2895.879, Time=0.93 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=2894.051, Time=1.57 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=2893.852, Time=1.09 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=2892.596, Time=0.72 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=2893.061, Time=0.98 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=2896.953, Time=0.94 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=2896.039, Time=0.58 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=2894.424, Time=1.23 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=2894.873, Time=1.42 sec
#  ARIMA(0,0,1)(2,0,0)[12]             : AIC=2946.584, Time=0.70 sec
#
# Best model:  ARIMA(0,0,1)(2,0,0)[12] intercept
# Total fit time: 18.879 seconds

# %%
print(model.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  219
# Model:             SARIMAX(0, 0, 1)x(2, 0, [], 12)   Log Likelihood               -1441.298
# Date:                             Sat, 08 Jun 2024   AIC                           2892.596
# Time:                                     10:11:04   BIC                           2909.542
# Sample:                                          0   HQIC                          2899.440
#                                              - 219
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    209.1291     34.625      6.040      0.000     141.266     276.992
# ma.L1          0.1583      0.076      2.084      0.037       0.009       0.307
# ar.S.L12       0.3450      0.075      4.599      0.000       0.198       0.492
# ar.S.L24       0.1130      0.084      1.350      0.177      -0.051       0.277
# sigma2      3.016e+04   2854.480     10.565      0.000    2.46e+04    3.58e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.04
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.59   Skew:                             0.51
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Obtenemos los valores de p, d, q, P, D y Q
p_value = model.order[0]
d_value = model.order[1]
q_value = model.order[2]
P_value = model.seasonal_order[0]
D_value = model.seasonal_order[1]
Q_value = model.seasonal_order[2]

print(f'El valor p sugerido es: {p_value}')
print(f'El valor d sugerido es: {d_value}')
print(f'El valor q sugerido es: {q_value}')
print(f'El valor P sugerido es: {P_value}')
print(f'El valor D sugerido es: {D_value}')
print(f'El valor Q sugerido es: {Q_value}')
# Out:
# El valor p sugerido es: 0
# El valor d sugerido es: 0
# El valor q sugerido es: 1
# El valor P sugerido es: 2
# El valor D sugerido es: 0
# El valor Q sugerido es: 0

# %% [markdown]
# Entrenamos el modelo y procedemos a realizar la imputacion de los valores faltantes en la serie de tiempo.

# %%
# Ajustamos el modelo ARIMA con los 6 valores encontrados
model = ARIMA(df_ARIMA[col], order=(p_value, d_value, q_value), seasonal_order=(P_value, D_value, Q_value, 12))
model_fit = model.fit()
# Out:
# c:\Users\nlmal\anaconda3\envs\TFM\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\nlmal\anaconda3\envs\TFM\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\nlmal\anaconda3\envs\TFM\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
df_n = df.copy()
# Preparar los datos
df_n['Fecha'] = pd.to_datetime(df_n['Fecha'])

# Entrenar el modelo ARIMA con los datos no nulos
model = ARIMA(df_n[col].dropna(), order=(p_value, d_value, q_value))
model_fit = model.fit()

# Crear una copia del DataFrame original para no modificar los datos originales
df_fill = df_n.copy()

# Usar el modelo entrenado para predecir los valores nulos
for i in df_fill[df_fill[col].isna()].index:
    df_fill.loc[i, col] = model_fit.predict(start=i, end=i).values[0]

# # Usar el modelo entrenado para predecir los valores nulos
# for i in df_fill[df_fill[col].isna()].index:
#     df_fill.loc[i, col] = model_fit.predict(n_periods=1)
# Out:
# c:\Users\nlmal\anaconda3\envs\TFM\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\nlmal\anaconda3\envs\TFM\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\nlmal\anaconda3\envs\TFM\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# seteamos el indice de la serie de tiempo
df_filled = df_fill.copy()
# utilizamos los datos originales para ver mejor los datos imputados
# para ello tomamos el dataframe original y renombramos la columna de precipitación
df_orig = df.copy()
df_orig = df_orig.rename(columns={col: 'Precipitación_original'})
df_orig = df_orig[['Precipitación_original']]

df_filled = df_filled.rename(columns={col: 'Precipitación_imputada'})

# cruzamos los datos originales con los datos imputados con join por fecha
df_filled = df_filled.join(df_orig, how='left')
df_filled

# Graficamos la serie de tiempo original y la serie de tiempo imputada, imprimos con los indices en als etiquetas rotados 90 grados
plt.figure(figsize=(10, 6))
plt.plot(df_filled['Precipitación_imputada'], label='Serie de Tiempo Imputada')
plt.plot(df_filled['Precipitación_original'], label='Serie de Tiempo Original')
plt.title('Serie de Tiempo Original vs Serie de Tiempo Imputada')
plt.xlabel('Fecha')
plt.ylabel('Precipitación')

plt.legend()
plt.show()

# %% [markdown]
# Podemos observar como con el modelo ARIMA predecimos los datos faltantes de nuestra serie de tiempo para pdoer trabajar con ella mas adelante.

# %%
# contamos valores nulos en nuestro dataframe
print(df_filled.isnull().sum())
# Out:
# Fecha                      0
# Mes                        0
# Año                        0
# Precipitación_imputada     0
# Precipitación_original    21
# dtype: int64

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               23050250   No. Observations:                  219
# Model:                 ARIMA(0, 0, 1)   Log Likelihood               -1458.203
# Date:                Sat, 08 Jun 2024   AIC                           2922.406
# Time:                        10:11:36   BIC                           2932.573
# Sample:                             0   HQIC                          2926.512
#                                 - 219
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        385.9283     16.900     22.836      0.000     352.805     419.051
# ma.L1          0.2811      0.067      4.220      0.000       0.151       0.412
# sigma2      3.555e+04   3662.449      9.706      0.000    2.84e+04    4.27e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 3.89
# Prob(Q):                              0.93   Prob(JB):                         0.14
# Heteroskedasticity (H):               0.74   Skew:                             0.32
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Procedemos a generar el codigo que se en cargue de tratar todas las estaciones de una zona hidrografica.

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt
from pmdarima import auto_arima
import shutil
import os
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

lista_zonas = ['MAGDALENA_MEDIO']
path = '../datos/separados_por_estacion/'

# %%
for zona in lista_zonas:
    print('Zona:',zona)
    path_zone = path+zona

    shutil.rmtree(f'../datos/imputados_SARIMA/{zona}/', ignore_errors=True)
    path_output = f'../datos/imputados_SARIMA/{zona}/'
    os.makedirs(path_output)


    for file in os.listdir(path_zone):
        print('Archivo:',file)
        col = file.split('.')[0]
        df = pd.read_csv(path_zone+'/'+file)

        df_ARIMA = df[["Fecha", col]]
        df_ARIMA['Fecha'] = pd.to_datetime(df_ARIMA['Fecha'])
        df_ARIMA.set_index('Fecha', inplace=True)

        df_ARIMA = df_ARIMA.dropna()

        result = adfuller(df_ARIMA[col])
        # Se podria guardar con los demas datos estadisticos
        # print('ADF Statistic:', result[0])
        # print('p-value:', result[1])
        image_path = f'../salidas/{zona}/{col}/SARIMA/'
        if os.path.exists(image_path):
            shutil.rmtree(image_path, ignore_errors=True)
        if not os.path.exists(image_path):
            os.makedirs(image_path)

        # Graficar la PACF
        plt.figure(figsize=(10, 6))
        plot_pacf(df_ARIMA[col], lags=40)
        plt.xlabel('Retrasos')
        plt.ylabel('Autocorrelación Parcial')
        plt.title('Autocorrelograma Parcial de la Precipitación')
        plt.savefig(f'{image_path}PACF.png')
        plt.close()

        model = auto_arima(df_ARIMA[col], seasonal=True, m=12, trace=False)
        # Ajustamos el modelo ARIMA con los 6 valores encontrados
        model = ARIMA(df_ARIMA[col], order=(model.order[0], model.order[1], model.order[2]), seasonal_order=(model.seasonal_order[0], model.seasonal_order[1], model.seasonal_order[2], 12))
        model_fit = model.fit()

        # Guardamos el resumen del modelo
        with open(f'{image_path}summary.txt', 'w') as f:
            f.write(str(model_fit.summary()))
        # Guardamos el modelo
        model_fit.save(f'{image_path}model.pkl')

        # Crear una copia del DataFrame original para no modificar los datos originales
        df_filled = df.copy()

        # Usar el modelo entrenado para predecir los valores nulos
        for i in df_filled[df_filled[col].isna()].index:
            df_filled.loc[i, col] = model_fit.predict(start=i, end=i).values[0]

        df_filled = df_filled.rename(columns={col: 'Precipitación_imputada'})

        df_orig = df.copy()
        df_orig = df_orig.rename(columns={col: 'Precipitación_original'})
        df_orig = df_orig[['Precipitación_original']]

        # cruzamos los datos originales con los datos imputados con join por fecha
        df_filled = df_filled.join(df_orig, how='left')

        indices = np.arange(len(df_filled))
        coef = np.polyfit(indices, df_filled['Precipitación_imputada'], 1)  # coef = [pendiente, intersección]
        df_filled['xlin'] = np.polyval(coef, indices)

        # Graficamos la serie de tiempo original y la serie de tiempo imputada, imprimos con los indices en als etiquetas rotados 90 gradosç
        plt.figure(figsize=(10, 6))
        plt.plot(df_filled['Precipitación_imputada'], label='Serie de Tiempo Imputada')
        plt.plot(df_filled['Precipitación_original'], label='Serie de Tiempo Original')
        plt.plot(df_filled['xlin'], label='Línea de Tendencia')
        plt.title('Serie de Tiempo Original vs Serie de Tiempo Imputada')
        plt.xlabel('Fecha')
        plt.ylabel('Precipitación')
        plt.legend()
        plt.savefig(f'{image_path}Serie_Tiempo_imputada.png')
        plt.close()

        df_filled['xint'] = model_fit.predict(start=0, end=len(df_filled)-1)
        df_filled['RESIDUALS'] = df_filled['Precipitación_original'] - df_filled['xint']
        df_filled.to_csv(f'{path_output}{col}.csv', index=False)
# Out:
# Zona: MAGDALENA_MEDIO
# Archivo: 23010020.csv
